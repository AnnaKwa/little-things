# %% [markdown]
# ## Plotting the rotation curves and error bars extracted from the little things paper

# %%
import numpy as np
import matplotlib.pyplot as plt

LT_radii, LT_vels = np.loadtxt("/Users/stephencoffey/Downloads/LT_NGC2366_vels.txt", unpack = True)

LT_err = np.loadtxt("/Users/stephencoffey/Downloads/NGC2366 Little Things Error Bars.txt", usecols = 1,unpack = True) - LT_vels

# %%
plt.scatter(LT_radii, LT_vels, color = "red")
plt.errorbar(LT_radii, LT_vels, xerr = None, yerr = LT_err)
# Out:
# [2.33250184 2.45353197 2.31278575 3.00100856 3.68231797 3.77908462
#  3.44744119 3.23998959 2.78151194 3.1676821  4.88078493 4.92883966
#  4.64720093 4.09443579 4.25431801 4.2394462  4.73688107 4.51902697
#  3.86616598 4.78659676 4.52193284 3.99439971 3.60987848 4.21349164
#  4.03975267 4.37956835 4.83289274 4.42358875 4.56679769 4.35699405
#  4.66046169 4.72694867 5.35400692 4.9409991  5.00969626 4.59215752
#  4.43589295 4.25054832 4.37708838 4.51241005 4.85435755 4.76616848
#  4.44478375 4.56332828 5.13024954 4.8792945  4.71885386 4.54880705
#  4.85952994 5.36253179 4.99550582 5.19303553 4.84215667 5.21538739
#  5.0030058  5.55235552 5.50208901 5.42534512 5.91722081 5.58836854
#  6.29196861 5.80856189 5.54190105 6.32733406 5.84898444 5.94149821
#  5.7632827  5.12659724 5.50677608 5.09538997]
# <ErrorbarContainer object of 3 artists>
